# %% [markdown]
# # Описание задачи
# Данный Python notebook разбит на две логических части.
#
# **Первая** – ознакомительная. Она демонстрирует, как осуществляется лемматизация – приведение слов в тексте к стандартной форме. Некоторые примеры представлены здесь. Для демонстрации используется библиотека Yandex MyStem. Ввиду того, что база данных, с которой мы работаем, очень большая, для проведения лемматизации недостаточно просто применить функцию mystem.lemmatize() к датафрейму: ее работа займет много часов, при этом наиболее вероятно, что в процессе закончится свободная оперативная память, и код завершится с ошибкой.
# В комментариях в коде схематично описан алгоритм обработки датафрейма, выполнение которого не затратит слишком много времени и ресурсов (запускать данный код не требуется, но понять принцип работы желательно).
#
# **Вторая часть кода** непосредственно связана с вашей задачей. Она загружает базу всех товаров (df_final) и выборку, сформированную по итогам вашей коллективной работы на первом этапе проекта (df_sample). Далее демонстрируется, как с помощью этой выборки можно обучить модели классификации (обычная логистическая регрессия и градиентный спуск с регуляризацией elastic net) и использовать полученную модель для out-of-sample классификации.

# %% [markdown]
# **Последовательность действий на данном этапе:**
# 1.	Ознакомиться с базовыми версиями моделей, предлагаемыми в данном ноутбуке. Они, ожидаемо, хорошо работают in-sample, но out-of-sample качество гораздо хуже
# 2.	Выбрать себе для анализа несколько товарных групп (3-5). Пожалуйста, используйте чат для координации, чтобы результаты получились более разнообразными. Справочник со всеми возможными товарами прилагаю в файле КИПЦ_веса.xlsx. Нас интересуют товары на семизначном уровне классификатора КИПЦ (например, 06.1.1.0.1.2, 01.1.4.4.4.1 и т. д.). По большинству товаров мы с вами набрали достаточно большую выборку, но лучше все равно перепроверить: задать targetProductCode в соответствующей ячейке и исполнить следующую за ней ячейку, посмотрев на сумму Y.sum(). У нас вряд ли получатся хорошие результаты, если товаров в группе меньше 30-40.
# 3.	Улучшить предлагаемые модели/предложить собственные. Вы можете, например, использовать иной классификатор (совсем не исчерпывающий список примеров есть, например, тут), улучшить работу моих классификаторов путем оптимизации гиперпараметров (l1_ratio, alpha и т.д.) через кросс-валидацию (примеры тут, тут, тут и в сотнях вопросов на stackoverflow)
# 4.	Сформировать единый датафрейм с результатами вашей классификации.

# %% [markdown]
# ## 1. Lemmatizing data

# %%
# install Python wrapper for Yandex MyStem
# !pip install pymystem3
# !pip install nltk
# !pip install distributed
# !pip install pyspark # takes 5-10 minutes
# !pip install fastparquet
# !pip install eli5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymystem3 in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pymystem3) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pymystem3) (2.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk) (4.64.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (2022.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (21.3)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from distributed) (0.12.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed) (6.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (1.0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from distributed) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from distributed) (57.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (1.7.0)
# Requirement already satisfied: dask==2022.02.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (2022.2.0)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (1.5.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed) (2.2.0)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.7/dist-packages (from distributed) (7.1.2)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed) (5.4.8)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed) (2.4.0)
# Requirement already satisfied: tornado>=5 in /usr/local/lib/python3.7/dist-packages (from distributed) (5.1.1)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask==2022.02.0->distributed) (2022.7.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask==2022.02.0->distributed) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->distributed) (3.0.9)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask==2022.02.0->distributed) (1.0.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed) (1.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2->distributed) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.7/dist-packages (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2022.7.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.3.5)
# Requirement already satisfied: cramjam>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (2.5.0)
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.7/dist-packages (from fastparquet) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.0->fastparquet) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=1.1.0->fastparquet) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: eli5 in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from eli5) (1.15.0)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from eli5) (0.8.10)
# Requirement already satisfied: jinja2>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (3.1.2)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from eli5) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.20 in /usr/local/lib/python3.7/dist-packages (from eli5) (1.0.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.7/dist-packages (from eli5) (0.10.1)
# Requirement already satisfied: attrs>17.1.0 in /usr/local/lib/python3.7/dist-packages (from eli5) (22.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2>=3.0.0->eli5) (2.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20->eli5) (1.1.0)

# %%
# load other dependencies
import pandas as pd
import nltk
from nltk.corpus import stopwords
from string import punctuation
from joblib import Parallel, delayed
from tqdm import tqdm
import os
from distributed import Client
import dask.dataframe as dd
import pyspark
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# this should automatically download and install MyStem
from pymystem3 import Mystem
m = Mystem()
# Out:
# Installing mystem to /root/.local/bin/mystem from http://download.cdn.yandex.net/mystem/mystem-3.1-linux-64bit.tar.gz

# %%
# commonly used words which can be considered as "noise" and have to be removed
russian_stopwords = stopwords.words("russian")

# %%
# custom function to perform lemmatization. Filters out stopwords, blank words,
# short words (<3 characters), punctuation and digits
def preprocess_text(text):
    tokens = m.lemmatize(text.lower())
    tokens = [token for token in tokens if token not in russian_stopwords\
               and token != " " \
               and len(token)>=3 \
               and token.strip() not in punctuation \
               and token.isdigit()==False]
    text = " ".join(tokens)
    return tokens

# %%
# all the goods available in the database
df = pd.read_csv('all_goods.csv')
df.head(30)
# Out:
#     web_price_id                                       product_name  \
# 0        6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1        5318090                  Calvin Klein Performance Футболка
# 2        8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3        6649792                                  Avocadoffka Кукла
# 4        7420308        Uniqcute Постельное белье 2 спальный поплин
# 5        5559609                               Swiss Navy Лубрикант
# 6        5487362                                     Lacoste Куртка
# 7        7931249                                      Briari Платье
# 8        2776174  4M Набор для опытов обучающий набор эксперимен...
# 9        7420346                     Flexpocket Держатель для масок
# 10       2941206                    Curaprox Ополаскиватель для рта
# 11       2999236  Контейнер для продуктов герметичный Phibo Bril...
# 12       5734435                        Полесье Набор для песочницы
# 13       5069288  Кардиган Intimissimi цвет серый Артикул MP002X...
# 14       5385755                          ORIGINAL MARINES Колготки
# 15       7846962  Доборная планка Delinia ID Петергоф грей 77х4 ...
# 16       7907155                   Копилка Art East Капитал КФ 59 4
# 17       8561462  Мы выйдем с собой погулять в лес отзывы распис...
# 18       8402128           Rivoli Люстра подвесной подвесная люстра
# 19       8644492  1 комн кв 35 м 4 9 этаж Москва ЮЗАО р н Обруче...
# 20       8816392  Боди 2 шт PlayToday цвет серый белый Артикул M...
# 21       8081974  Топ Bershka цвет голубой Артикул IX001XW010ZA ...
# 22       8218412                 Баклажаны Metro Chef в масле 1600г
# 23       8402479                         Flying Toys Фиджет спиннер
# 24       4890795  Джинсы Acoola цвет синий Артикул MP002XB00UTT ...
# 25      10841075   Universal store kids Перчатки подкладка из флиса
# 26        137148  Соска Chicco Natural Feeling силиконовая с 2 м...
# 27       4921382                                  YuXin Головоломка
# 28       5185678  Халат домашний КотМарКот цвет белый Артикул MP...
# 29       5258643  1 комн кв 67 м 4 19 этаж Москва ЮЗАО р н Ломон...
#
#     contributor_id                    moment
# 0                1  2021-04-23T14:49:06.857Z
# 1                1  2021-04-08T02:32:39.977Z
# 2                4      2021-11-15T20:21:20Z
# 3                4      2021-04-25T13:21:35Z
# 4                4      2021-06-13T06:52:33Z
# 5                4      2021-04-13T02:36:21Z
# 6                4      2021-04-13T01:37:18Z
# 7                4      2021-07-08T07:30:11Z
# 8                1  2021-03-22T14:57:00.060Z
# 9                4      2021-06-13T06:47:38Z
# 10               1  2021-03-19T16:20:05.443Z
# 11               4      2021-12-10T13:46:15Z
# 12               1  2021-04-16T20:51:32.917Z
# 13               4      2021-03-20T21:21:16Z
# 14               4      2021-04-13T01:42:13Z
# 15               4      2021-06-23T00:29:37Z
# 16               4      2021-06-26T00:24:52Z
# 17               1  2021-08-20T21:24:33.693Z
# 18               4      2021-08-10T12:06:46Z
# 19               4      2021-09-15T12:18:42Z
# 20               4      2021-09-30T17:56:09Z
# 21               4      2021-07-06T23:32:36Z
# 22               4      2021-07-19T10:55:25Z
# 23               4      2021-08-10T11:46:29Z
# 24               4      2021-04-13T21:20:13Z
# 25               1  2022-04-08T03:29:15.697Z
# 26               1  2021-03-19T16:20:05.443Z
# 27               4      2021-03-26T02:28:17Z
# 28               4      2021-03-27T21:11:41Z
# 29               4      2021-04-06T17:08:14Z

# %%
# download the necessary files from MyDrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# df['name_lemm'] = df['product_name'].apply(preprocess_text)
# the line above would be the standard way to lemmatize the data. However, due to internal restrictons of pymystem3 it takes
# several hours to run this single line of code.
#
# The reason why it takes so long is that for EACH row python makes a separete call to mystem.exe,
# which takes approx. 1 second to launch. The following code circumvents this restriction.
# 1. We use parallel computation (Client(n_workers=4)) so that the CPU of the computer is used more efficiently
# 2. We load the dataset all_goods.csv and break it int little pieces with df.repartition.
# They are saved in .parquet format in a separete folder
# 3. We apply the functon preprocess_df to each of these little pieces.
#
# preprocess_df() works in the following way:
# 1. We take the column with product names and transofrm it to a list prodnames.
# 2. Next we transform the list to a single string merged_text, where individual product names are separated with a key word "breakword"
# 3. Then we use preprocess_text() defined earlier to lemmatize and clear the product names.
# Using this function on a single string (rather than on a column of a dataframe) is several dozen times faster.
# 4. In a for loop we restore a list from the string and assign it to product_name_lemm

# %%
def preprocess_df(df):
    m = Mystem()
    prodnames = df['product_name'].tolist()
    merged_text = " breakword ".join([str(x) for x in prodnames])
    doc = []
    res = []
    l = preprocess_text(merged_text)
    for t in l:
        if t != 'breakword':
            doc.append(t)
        else:
            res.append(doc)
            doc = []
    res.append(doc)
    res = [' '.join(x) for x in res]
    df['product_name_lemm'] = res
    m.close()
    return df
if __name__ == '__main__':
    client = Client(n_workers=4)

    # Splitting the big file
    df = dd.read_csv('all_goods.csv', dtype={'web_price_id': int, 'product_name': str, 'contributor_id': int, 'moment': str}) # Read a big data file
    df = df.repartition(npartitions=df.npartitions*100) # increase the value if the df is very large
    df.to_parquet('int/') # convert .csv file to .parquet parts

    # Loading the splitted file parts
    df = dd.read_parquet('int/')

    # Applying the function
    df = df.map_partitions(preprocess_df, meta={'web_price_id': int, 'product_name': str, 'contributor_id': int, 'moment': str, 'product_name_lemm' : str}) # Be sure not to '.compute' here

    df.to_parquet('preprocesed.parquet')
    client.close()

# %%
df_final_dask = dd.read_parquet('preprocesed.parquet')
df_final_dask

# %%
df_final = df_final_dask.compute()
df_final.head()

# %%
df_final.to_csv('all_goods_lemm.csv', index=False)

# %% [markdown]
# ## 2. Working with lemmatized data

# %%
df_final = pd.read_csv('all_goods_lemm.csv')
df_final = df_final.drop(columns=['contributor_id', 'moment'])
df_final = df_final.drop_duplicates(subset=['web_price_id'])
df_final = df_final[~df_final.product_name_lemm.isnull()]
df_final = df_final[~df_final.product_name.isnull()]
df_final.head()
# Out:
#    web_price_id                                       product_name  \
# 0       6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1       5318090                  Calvin Klein Performance Футболка
# 2       8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3       6649792                                  Avocadoffka Кукла
# 4       7420308        Uniqcute Постельное белье 2 спальный поплин
#
#                                    product_name_lemm
# 0                     игроленд игрушка интерактивный
# 1                  calvin klein performance футболка
# 2  шиповка nike цвет черный артикул rtlaao360101 ...
# 3                                  avocadoffka кукла
# 4          uniqcute постельный белье спальный поплин

# %%
df_final
# Out:
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 9300025       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 9300026       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 9300028      10806102                   R O C S Зубная щетка мягкая 1 шт
# 9300029       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 9300030      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm
# 0                           игроленд игрушка интерактивный
# 1                        calvin klein performance футболка
# 2        шиповка nike цвет черный артикул rtlaao360101 ...
# 3                                        avocadoffka кукла
# 4                uniqcute постельный белье спальный поплин
# ...                                                    ...
# 9300025                       мойка кухонный omoikiri taki
# 9300026  перчатка regatta цвет черный артикул re036dmji...
# 9300028                                зубной щетка мягкий
# 9300029      ацетилсалициловый кислота таблетка 500мг 30шт
# 9300030                         парник рассада дуга парник
#
# [4131972 rows x 3 columns]

# %%
df_sample = pd.read_csv('sample.csv', sep=';', dtype={'web_price_id': object, 'product_name': str, 'contributor_id': object, 'moment': str, 'rosstat_name': str})
df_sample = df_sample.drop(columns=['contributor_id', 'moment'])
df_sample = df_sample[~df_sample['web_price_id'].isnull()]
df_sample['web_price_id'] = df_sample['web_price_id'].astype(int)
df_sample = df_sample.drop_duplicates(subset=['web_price_id'])
df_sample = df_sample[df_sample['web_price_id'].isin(df_final['web_price_id'])]
df_sample = pd.merge(df_sample, df_final[['product_name_lemm', 'web_price_id']], on="web_price_id", how='left')
df_sample = df_sample[~df_sample.product_name_lemm.isnull()]
df_sample = df_sample[~df_sample.product_name.isnull()]
df_sample
# Out:
#        web_price_id                               product_name  \
# 0           8164323             КИСЕЯ Ткань для рукоделия бязь
# 1           8503735      1 Метр ткани Ткань для рукоделия бязь
# 2           7021870  Мегахлопок Ткань Бязь Валенсия 100х150 см
# 3           5293185      1 Метр ткани Ткань для рукоделия бязь
# 4           5293180      1 Метр ткани Ткань для рукоделия бязь
# ...             ...                                        ...
# 42190       8363100                            ОрехМолл Бананы
# 42191       7267302                              ВКУСНО Бананы
# 42192       7622000                        Фреш Продукт Бананы
# 42193       7399774                     Казанские орехи Бананы
# 42194      10832447                              Орехов Бананы
#
#                              rosstat_name  \
# 0      Ткани хлопчатобумажные бельевые, м
# 1      Ткани хлопчатобумажные бельевые, м
# 2      Ткани хлопчатобумажные бельевые, м
# 3      Ткани хлопчатобумажные бельевые, м
# 4      Ткани хлопчатобумажные бельевые, м
# ...                                   ...
# 42190                          Бананы, кг
# 42191                          Бананы, кг
# 42192                          Бананы, кг
# 42193                          Бананы, кг
# 42194                          Бананы, кг
#
#                             product_name_lemm
# 0                  кисея ткань рукоделие бязь
# 1             метр ткань ткань рукоделие бязь
# 2      мегахлопка ткань бязь валенсия 100х150
# 3             метр ткань ткань рукоделие бязь
# 4             метр ткань ткань рукоделие бязь
# ...                                       ...
# 42190                          орехмолл банан
# 42191                            вкусно банан
# 42192                      фреш продукт банан
# 42193                    казанский орех банан
# 42194                              орех банан
#
# [42195 rows x 4 columns]

# %%
df = pd.merge(df_final, df_sample[['web_price_id', 'rosstat_name']], on='web_price_id', how='left')
df
# Out:
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 4131967       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 4131968       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 4131969      10806102                   R O C S Зубная щетка мягкая 1 шт
# 4131970       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 4131971      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm rosstat_name
# 0                           игроленд игрушка интерактивный          NaN
# 1                        calvin klein performance футболка          NaN
# 2        шиповка nike цвет черный артикул rtlaao360101 ...          NaN
# 3                                        avocadoffka кукла          NaN
# 4                uniqcute постельный белье спальный поплин          NaN
# ...                                                    ...          ...
# 4131967                       мойка кухонный omoikiri taki          NaN
# 4131968  перчатка regatta цвет черный артикул re036dmji...          NaN
# 4131969                                зубной щетка мягкий          NaN
# 4131970      ацетилсалициловый кислота таблетка 500мг 30шт          NaN
# 4131971                         парник рассада дуга парник          NaN
#
# [4131972 rows x 4 columns]

# %% [markdown]
# ## Work with 4 chosen categories

# %% [markdown]
# 1. Мороженое сливочное, кг
# 2. Зефир, пастила, кг
# 3. Футболка детская, шт
# 4. Джемпер женский, шт

# %% [markdown]
# ### 1 category

# %%
targetProductCode = 'Мороженое сливочное, кг'

# %%
Y = df_sample['rosstat_name'].apply(lambda x: 1 if x == targetProductCode else 0)
Y.sum() # number of products in a category (>30)
# Out:
# 188

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDClassifier
import numpy as np
import operator
import eli5

# %%
tfidf_vectorizer=TfidfVectorizer(use_idf=True, max_df=0.95, ngram_range=(1, 2))
tfidf_vectorizer.fit_transform(df_sample['product_name_lemm'].values)
X = tfidf_vectorizer.transform(df_sample['product_name_lemm'].values)

# %%
scikit_log_reg = LogisticRegression(verbose=1, solver='liblinear', random_state=0, C=5, penalty='l2',max_iter=1000)

# %%
model=scikit_log_reg.fit(X,Y)
# Out:
# [LibLinear]

# %%
eli5.show_weights(estimator=model,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +22.671
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мороженое
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.149
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         сливочный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.487
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мороженое сливочный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.116
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пломбир
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.697
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         эскимо
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.556
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         шоколадный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.87%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.250
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         шоколад
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.095
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         глазурь
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.597
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         70г
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.490
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         вафельный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.100
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         80г
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.042
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         movenpick
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.016
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         кусочек
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.986
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         рожок
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.897
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ванильный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         baskin robbins
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         baskin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.817
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         robbins
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.815
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         карамель
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.812
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мороженое movenpick
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.81%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.646
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         farinari
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.638
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мороженое baskin
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.6

# %%
EN=SGDClassifier(loss='log', penalty='elasticnet')
model2=EN.fit(X,Y)

# %%
eli5.show_weights(estimator=model2,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))

# %%
probs = model.predict_proba(X)
probs2 = model2.predict_proba(X)

# %%
# A function which returns goods with highest predicted probability of being in a category
def highest_prob(df, probs, k):
    best_n = np.argsort(probs, axis=0)
    d = pd.DataFrame()
    d['product_name'] = np.flip(df['product_name'].values[best_n[-k:,1]])
    d['prob'] = np.flip(probs[best_n[-k:,1],1])
    return d

# %%
highest_prob(df_sample, probs, 40)

# %%
highest_prob(df_sample, probs2, 20)

# %%
# Now let's try to predict out of sample

# %%
trainid = df_sample['web_price_id'].tolist()
test_df = df_final[~df_final.web_price_id.isin(trainid)]

# %%
testX = tfidf_vectorizer.transform(test_df['product_name_lemm'].values)
testprobs = model.predict_proba(testX)

# %%
testprobs = model.predict(testX)

# %%
testprobs
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# add a new column "proba" to testprobs
test_df['proba']=testprobs
test_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 9300025       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 9300026       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 9300028      10806102                   R O C S Зубная щетка мягкая 1 шт
# 9300029       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 9300030      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm  proba
# 0                           игроленд игрушка интерактивный      0
# 1                        calvin klein performance футболка      0
# 2        шиповка nike цвет черный артикул rtlaao360101 ...      0
# 3                                        avocadoffka кукла      0
# 4                uniqcute постельный белье спальный поплин      0
# ...                                                    ...    ...
# 9300025                       мойка кухонный omoikiri taki      0
# 9300026  перчатка regatta цвет черный артикул re036dmji...      0
# 9300028                                зубной щетка мягкий      0
# 9300029      ацетилсалициловый кислота таблетка 500мг 30шт      0
# 9300030                         парник рассада дуга парник      0
#
# [4089777 rows x 4 columns]

# %%
test_df['proba'].sum()
# Out:
# 1603

# %%
test_df1 = test_df[test_df['proba']==1]
test_df1 = test_df1.assign(Rosstat_name='Мороженое сливочное, кг')
test_df1
# Out:
#          web_price_id                                       product_name  \
# 9732           141155  Коктейль молочный Большая Кружка Клубника моро...
# 31221           27197  Елочное украшение Kurt S Adler Рожок с морожен...
# 36352         7110407   Слайм ПЛЮХ Зефирка мороженое контейнер 120г ПЛЮХ
# 40218          153758  Мороженое Русский Холодъ Пломбир настоящий рож...
# 51549         6753929  Мороженое молочное Bounty кокос в шоколадной г...
# ...               ...                                                ...
# 9262873       7774943            Маршмеллоу PiratMarmelad Мороженое 200г
# 9270128       8016013  Мороженое пломбир Филевское с вишней кусочками...
# 9280308      10337999  Игровой набор Хома Дома Тележка хомодильник дл...
# 9289007       6973977  Мороженое Б Ю Александров Пломбир с кленовым с...
# 9299418        153789  Мороженое Вологодский Пломбир в сахарном рожке...
#
#                                          product_name_lemm  proba  \
# 9732     коктейль молочный большой кружок клубника моро...      1
# 31221    елочный украшение kurt adler рожок мороженое а...      1
# 36352    слайм плюх зефирка мороженое контейнер 120г плюха      1
# 40218    мороженое русский холод пломбир настоящий рожо...      1
# 51549    мороженое молочный bounty кокос шоколадный гла...      1
# ...                                                    ...    ...
# 9262873            маршмеллоу piratmarmelad мороженое 200г      1
# 9270128  мороженое пломбир филевский вишня кусочек минд...      1
# 9280308  игровой набор хома дом тележка хомодильник мор...      1
# 9289007  мороженое александров пломбир кленовый сироп м...      1
# 9299418  мороженое вологодский пломбир сахарный рожок 130г      1
#
#                     Rosstat_name
# 9732     Мороженое сливочное, кг
# 31221    Мороженое сливочное, кг
# 36352    Мороженое сливочное, кг
# 40218    Мороженое сливочное, кг
# 51549    Мороженое сливочное, кг
# ...                          ...
# 9262873  Мороженое сливочное, кг
# 9270128  Мороженое сливочное, кг
# 9280308  Мороженое сливочное, кг
# 9289007  Мороженое сливочное, кг
# 9299418  Мороженое сливочное, кг
#
# [1603 rows x 5 columns]

# %%
test_df1.to_csv('file1.csv')

# %%
testprobs2 = model2.predict_proba(testX)

# %%
highest_prob(test_df, testprobs, 40)

# %%
highest_prob(test_df, testprobs2, 40)

# %% [markdown]
# # 2 category

# %%
targetProductCode = 'Зефир, пастила, кг'

# %%
Y = df_sample['rosstat_name'].apply(lambda x: 1 if x == targetProductCode else 0)
Y.sum() # number of products in a category (>30)
# Out:
# 224

# %%
tfidf_vectorizer=TfidfVectorizer(use_idf=True, max_df=0.95, ngram_range=(1, 2))
tfidf_vectorizer.fit_transform(df_sample['product_name_lemm'].values)
X = tfidf_vectorizer.transform(df_sample['product_name_lemm'].values)

# %%
scikit_log_reg = LogisticRegression(verbose=1, solver='liblinear', random_state=0, C=5, penalty='l2',max_iter=1000)

# %%
model=scikit_log_reg.fit(X,Y)
# Out:
# [LibLinear]

# %%
eli5.show_weights(estimator=model,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +22.673
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пастила
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +21.813
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         зефир
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.261
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         белевский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.32%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.752
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         воздушный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.60%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.497
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         яблочный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.66%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.437
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ассорти
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.402
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         вкус
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.168
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         яблоко
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.969
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ваниль
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.788
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         традиция
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.768
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ванильный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.353
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пастила яблоко
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.07%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.221
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         зефир воздушный
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.197
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пастила ассорти
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.169
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         нева
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.114
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         аромат ваниль
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.074
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         клубника
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         малина
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.013
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         старый традиция
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.914
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         белевская
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.866
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         клюква
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.856
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мануфактура
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.819

# %%
EN=SGDClassifier(loss='log', penalty='elasticnet')
model2=EN.fit(X,Y)

# %%
eli5.show_weights(estimator=model2,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))

# %%
probs = model.predict_proba(X)
probs2 = model2.predict_proba(X)

# %%
highest_prob(df_sample, probs, 50)

# %%
highest_prob(df_sample, probs2, 20)

# %%
trainid = df_sample['web_price_id'].tolist()
test_df = df_final[~df_final.web_price_id.isin(trainid)]

# %%
testX = tfidf_vectorizer.transform(test_df['product_name_lemm'].values)
testprobs = model.predict_proba(testX)

# %%
testprobs_2 = model.predict(testX)

# %%
testprobs_2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
test_df['proba']=testprobs_2
test_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 9300025       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 9300026       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 9300028      10806102                   R O C S Зубная щетка мягкая 1 шт
# 9300029       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 9300030      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm  proba
# 0                           игроленд игрушка интерактивный      0
# 1                        calvin klein performance футболка      0
# 2        шиповка nike цвет черный артикул rtlaao360101 ...      0
# 3                                        avocadoffka кукла      0
# 4                uniqcute постельный белье спальный поплин      0
# ...                                                    ...    ...
# 9300025                       мойка кухонный omoikiri taki      0
# 9300026  перчатка regatta цвет черный артикул re036dmji...      0
# 9300028                                зубной щетка мягкий      0
# 9300029      ацетилсалициловый кислота таблетка 500мг 30шт      0
# 9300030                         парник рассада дуга парник      0
#
# [4089777 rows x 4 columns]

# %%
test_df['proba'].sum()
# Out:
# 1254

# %%
test_df2 = test_df[test_df['proba']==1]
test_df2 = test_df2.assign(Rosstat_name='Зефир, пастила, кг')
test_df2
# Out:
#          web_price_id                                       product_name  \
# 8562          2785197  Петербургский КондитерЪ Зефир в шоколаде натур...
# 61872         8831362  Пастила ВкусВилл Яблочная с брусникой без саха...
# 94890        11106866           Jess Food Пастила Ассорти фруктов и ягод
# 99160         8849293             Пастила PastiLab медовая сливовая 250г
# 100448        8831422                       Зефир ВкусВилл ванильный 80г
# ...               ...                                                ...
# 9240679       8105982           Белёвская пастильная мануфактура Пастила
# 9253504       5724365    Пастила БЕЛЕВСКАЯ ПАСТИЛА Заварная Ваниль 250 г
# 9273181       9682816                   Бальзам для губ Martinelia зефир
# 9282117       2784684                      Иван поле Пастила яблоко 9 шт
# 9282790       2785188                        НЕВА Зефир воздушный ваниль
#
#                                          product_name_lemm  proba  \
# 8562     петербургский кондитер зефир шоколад натуральн...      1
# 61872        пастила вкусвилл яблочный брусника сахар 200г      1
# 94890                jess food пастила ассорти фрукт ягода      1
# 99160               пастила pastilab медовый сливовый 250г      1
# 100448                        зефир вкусвилл ванильный 80г      1
# ...                                                    ...    ...
# 9240679           белевская пастильный мануфактура пастила      1
# 9253504          пастила белевская пастила заварной ваниль      1
# 9273181                      бальзам губа martinelia зефир      1
# 9282117                           иван поле пастила яблоко      1
# 9282790                        нева зефир воздушный ваниль      1
#
#                Rosstat_name
# 8562     Зефир, пастила, кг
# 61872    Зефир, пастила, кг
# 94890    Зефир, пастила, кг
# 99160    Зефир, пастила, кг
# 100448   Зефир, пастила, кг
# ...                     ...
# 9240679  Зефир, пастила, кг
# 9253504  Зефир, пастила, кг
# 9273181  Зефир, пастила, кг
# 9282117  Зефир, пастила, кг
# 9282790  Зефир, пастила, кг
#
# [1254 rows x 5 columns]

# %%
test_df2.to_csv('file2.csv')

# %%
testprobs2 = model2.predict_proba(testX)

# %%
highest_prob(test_df, testprobs, 40)

# %%
highest_prob(test_df, testprobs2, 40)

# %% [markdown]
# ### 3 category

# %%
targetProductCode = 'Футболка детская, шт'

# %%
Y = df_sample['rosstat_name'].apply(lambda x: 1 if x == targetProductCode else 0)
Y.sum() # number of products in a category (>30)
# Out:
# 115

# %%
tfidf_vectorizer=TfidfVectorizer(use_idf=True, max_df=0.95, ngram_range=(1, 2))
tfidf_vectorizer.fit_transform(df_sample['product_name_lemm'].values)
X = tfidf_vectorizer.transform(df_sample['product_name_lemm'].values)

# %%
scikit_log_reg = LogisticRegression(verbose=1, solver='liblinear', random_state=0, C=5, penalty='l2',max_iter=1000)

# %%
model=scikit_log_reg.fit(X,Y)
# Out:
# [LibLinear]

# %%
eli5.show_weights(estimator=model,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +18.173
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         футболка
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.999
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         мальчик
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.18%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.574
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         артикул
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.90%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.897
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         цвет
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +5.048
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         девочка
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.04%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.871
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         футболка детский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.98%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.267
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         футболка мальчик
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lets
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.056
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         детский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.971
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         белый артикул
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.833
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         детский футболка
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.59%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.806
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         футболка девочка
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.711
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         цвет белый
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.68%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.036
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         оранжевый
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.974
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         белый
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.13%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.740
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         рукав
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.701
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         lets lets
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.699
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         belka
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.696
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         светиться темнота
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.696
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         темнота
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.688
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         футболка puma
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.658
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         светиться
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 96.31%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">

# %%
EN=SGDClassifier(loss='log', penalty='elasticnet')
model2=EN.fit(X,Y)

# %%
eli5.show_weights(estimator=model2,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))

# %%
probs = model.predict_proba(X)
probs2 = model2.predict_proba(X)

# %%
highest_prob(df_sample, probs, 50)

# %%
highest_prob(df_sample, probs2, 20)

# %%
trainid = df_sample['web_price_id'].tolist()
test_df = df_final[~df_final.web_price_id.isin(trainid)]

# %%
testX = tfidf_vectorizer.transform(test_df['product_name_lemm'].values)
testprobs = model.predict_proba(testX)

# %%
testprobs_3 = model.predict(testX)

# %%
test_df['proba']=testprobs_3
test_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 9300025       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 9300026       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 9300028      10806102                   R O C S Зубная щетка мягкая 1 шт
# 9300029       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 9300030      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm  proba
# 0                           игроленд игрушка интерактивный      0
# 1                        calvin klein performance футболка      0
# 2        шиповка nike цвет черный артикул rtlaao360101 ...      0
# 3                                        avocadoffka кукла      0
# 4                uniqcute постельный белье спальный поплин      0
# ...                                                    ...    ...
# 9300025                       мойка кухонный omoikiri taki      0
# 9300026  перчатка regatta цвет черный артикул re036dmji...      0
# 9300028                                зубной щетка мягкий      0
# 9300029      ацетилсалициловый кислота таблетка 500мг 30шт      0
# 9300030                         парник рассада дуга парник      0
#
# [4089777 rows x 4 columns]

# %%
test_df['proba'].sum()
# Out:
# 32128

# %%
test_df3 = test_df[test_df['proba']==1]
test_df3 = test_df3.assign(Rosstat_name='Футболка детская, шт')
test_df3
# Out:
#          web_price_id                                       product_name  \
# 368           8482639  Футболка Ice Play цвет синий Артикул RTLAAC395...
# 585           5562496                                  Богатырь Футболка
# 657           1681256                                     IMRON Футболка
# 689           1681257                                     IMRON Футболка
# 695           1681258                                     IMRON Футболка
# ...               ...                                                ...
# 9299880       9684069                                    Футболка Kaftan
# 9299885       9684070                                    Футболка Kaftan
# 9299925       9684071                                    Футболка Kaftan
# 9299926       9684072                                    Футболка Kaftan
# 9300013       9684079                                    Футболка Minaku
#
#                                          product_name_lemm  proba  \
# 368      футболка ice play цвет синий артикул rtlaac395...      1
# 585                                      богатырь футболка      1
# 657                                         imron футболка      1
# 689                                         imron футболка      1
# 695                                         imron футболка      1
# ...                                                    ...    ...
# 9299880                                    футболка kaftan      1
# 9299885                                    футболка kaftan      1
# 9299925                                    футболка kaftan      1
# 9299926                                    футболка kaftan      1
# 9300013                                    футболка minaku      1
#
#                  Rosstat_name
# 368      Футболка детская, шт
# 585      Футболка детская, шт
# 657      Футболка детская, шт
# 689      Футболка детская, шт
# 695      Футболка детская, шт
# ...                       ...
# 9299880  Футболка детская, шт
# 9299885  Футболка детская, шт
# 9299925  Футболка детская, шт
# 9299926  Футболка детская, шт
# 9300013  Футболка детская, шт
#
# [32128 rows x 5 columns]

# %%
test_df3.to_csv('file3.csv')

# %%
testprobs2 = model2.predict_proba(testX)

# %%
highest_prob(test_df, testprobs, 40)

# %%
highest_prob(test_df, testprobs2, 40)

# %% [markdown]
# ### 4 category

# %%
targetProductCode = 'Джемпер женский, шт'

# %%
Y = df_sample['rosstat_name'].apply(lambda x: 1 if x == targetProductCode else 0)
Y.sum() # number of products in a category v
# Out:
# 144

# %%
tfidf_vectorizer=TfidfVectorizer(use_idf=True, max_df=0.95, ngram_range=(1, 2))
tfidf_vectorizer.fit_transform(df_sample['product_name_lemm'].values)
X = tfidf_vectorizer.transform(df_sample['product_name_lemm'].values)

# %%
scikit_log_reg = LogisticRegression(verbose=1, solver='liblinear', random_state=0, C=5, penalty='l2',max_iter=1000)

# %%
model=scikit_log_reg.fit(X,Y)
# Out:
# [LibLinear]

# %%
eli5.show_weights(estimator=model,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +11.804
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 81.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +10.510
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         свитер
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.22%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +9.981
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         толстовка женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.24%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.397
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         джемпер женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +8.228
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         одежда
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.980
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         толстовка
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +7.546
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пуловер
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.19%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.952
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         свитшот женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.84%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.490
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         джемпер
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.359
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         свитшот
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 87.05%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +6.346
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         худить
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.89%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.455
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         свитер женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +4.347
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         артикул
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.65%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.387
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         цвет
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.77%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +3.317
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         оверсайз
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.619
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         пуловер женский
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.207
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         женский inextenso
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 93.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.134
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         женский оверсайз
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.08%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +2.075
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         капюшон
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.946
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         женский sportalm
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.946
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         sportalm
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.925
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         zolla цвет
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; b

# %%
EN=SGDClassifier(loss='log', penalty='elasticnet')
model2=EN.fit(X,Y)

# %%
eli5.show_weights(estimator=model2,
                  feature_names= list(tfidf_vectorizer.get_feature_names_out()),
                 top=(50, 5))

# %%
probs = model.predict_proba(X)
probs2 = model2.predict_proba(X)

# %%
highest_prob(df_sample, probs, 50)

# %%
highest_prob(df_sample, probs2, 20)

# %%
trainid = df_sample['web_price_id'].tolist()
test_df = df_final[~df_final.web_price_id.isin(trainid)]

# %%
testX = tfidf_vectorizer.transform(test_df['product_name_lemm'].values)
testprobs = model.predict_proba(testX)

# %%
testprobs_4 = model.predict(testX)

# %%
testprobs_4
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
test_df['proba']=testprobs_4
test_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          web_price_id                                       product_name  \
# 0             6611458                     ИГРОЛЕНД Игрушки интерактивные
# 1             5318090                  Calvin Klein Performance Футболка
# 2             8482341  Шиповки Nike цвет черный Артикул RTLAAO360101 ...
# 3             6649792                                  Avocadoffka Кукла
# 4             7420308        Uniqcute Постельное белье 2 спальный поплин
# ...               ...                                                ...
# 9300025       7184397    Мойка кухонная Omoikiri Taki 54 U IF IN 4973046
# 9300026       8682610  Перчатки Regatta цвет черный Артикул RE036DMJI...
# 9300028      10806102                   R O C S Зубная щетка мягкая 1 шт
# 9300029       9063186      Ацетилсалициловая кислота таблетки 500мг 30шт
# 9300030      11280452                Парник для рассады Дуга для парника
#
#                                          product_name_lemm  proba
# 0                           игроленд игрушка интерактивный      0
# 1                        calvin klein performance футболка      0
# 2        шиповка nike цвет черный артикул rtlaao360101 ...      0
# 3                                        avocadoffka кукла      0
# 4                uniqcute постельный белье спальный поплин      0
# ...                                                    ...    ...
# 9300025                       мойка кухонный omoikiri taki      0
# 9300026  перчатка regatta цвет черный артикул re036dmji...      0
# 9300028                                зубной щетка мягкий      0
# 9300029      ацетилсалициловый кислота таблетка 500мг 30шт      0
# 9300030                         парник рассада дуга парник      0
#
# [4089777 rows x 4 columns]

# %%
test_df['proba'].sum()
# Out:
# 13467

# %%
test_df4 = test_df[test_df['proba']==1]
test_df4 = test_df4.assign(Rosstat_name='Джемпер женский, шт')
test_df4
# Out:
#          web_price_id                                       product_name  \
# 190           8409215                                      Mi Kar Свитер
# 230           8409246                                      Mi Kar Свитер
# 231           8409247                                      Mi Kar Свитер
# 789           5114136  Джемпер Old Seams цвет черный Артикул OL021EML...
# 1016         10557913  Kit Kate Декор для одежды Термотрансфер для од...
# ...               ...                                                ...
# 9299454       8980597  Худи PUMA цвет бежевый Артикул RTLAAU909101 Од...
# 9299492       2022704                                        VAY Пуловер
# 9299498       7322506  Джемпер Eterna цвет голубой Артикул MP002XM1ZQ...
# 9299538       2024252                                  Дважды Два Свитер
# 9299659       9684056                                   Толстовка Minaku
#
#                                          product_name_lemm  proba  \
# 190                                             kar свитер      1
# 230                                             kar свитер      1
# 231                                             kar свитер      1
# 789      джемпер old seams цвет черный артикул ol021eml...      1
# 1016     kit kate декор одежда термотрансфер одежда тер...      1
# ...                                                    ...    ...
# 9299454  худить puma цвет бежевый артикул rtlaau909101 ...      1
# 9299492                                        vay пуловер      1
# 9299498  джемпер eterna цвет голубой артикул mp002xm1zq...      1
# 9299538                                      дважды свитер      1
# 9299659                                   толстовка minaku      1
#
#                 Rosstat_name
# 190      Джемпер женский, шт
# 230      Джемпер женский, шт
# 231      Джемпер женский, шт
# 789      Джемпер женский, шт
# 1016     Джемпер женский, шт
# ...                      ...
# 9299454  Джемпер женский, шт
# 9299492  Джемпер женский, шт
# 9299498  Джемпер женский, шт
# 9299538  Джемпер женский, шт
# 9299659  Джемпер женский, шт
#
# [13467 rows x 5 columns]

# %%
test_df4.to_csv('file4.csv')

# %%
testprobs2 = model2.predict_proba(testX)

# %%
highest_prob(test_df, testprobs, 40)

# %%
highest_prob(test_df, testprobs2, 40)

# %%
import glob

# %%
files = glob.glob('*.csv')
files
# Out:
# ['file2.csv', 'file4.csv', 'file3.csv', 'file1.csv']

# %%
files_combined = pd.DataFrame()

for file in files:
    data = pd.read_csv(file)
    data['filename'] = file
    files_combined = pd.concat([files_combined, data])
del files_combined['product_name_lemm']
del files_combined['filename']
del files_combined['proba']
del files_combined['Unnamed: 0']

files_combined
# Out:
#       web_price_id                                       product_name  \
# 0          2785197  Петербургский КондитерЪ Зефир в шоколаде натур...
# 1          8831362  Пастила ВкусВилл Яблочная с брусникой без саха...
# 2         11106866           Jess Food Пастила Ассорти фруктов и ягод
# 3          8849293             Пастила PastiLab медовая сливовая 250г
# 4          8831422                       Зефир ВкусВилл ванильный 80г
# ...            ...                                                ...
# 1598       7774943            Маршмеллоу PiratMarmelad Мороженое 200г
# 1599       8016013  Мороженое пломбир Филевское с вишней кусочками...
# 1600      10337999  Игровой набор Хома Дома Тележка хомодильник дл...
# 1601       6973977  Мороженое Б Ю Александров Пломбир с кленовым с...
# 1602        153789  Мороженое Вологодский Пломбир в сахарном рожке...
#
#                  Rosstat_name
# 0          Зефир, пастила, кг
# 1          Зефир, пастила, кг
# 2          Зефир, пастила, кг
# 3          Зефир, пастила, кг
# 4          Зефир, пастила, кг
# ...                       ...
# 1598  Мороженое сливочное, кг
# 1599  Мороженое сливочное, кг
# 1600  Мороженое сливочное, кг
# 1601  Мороженое сливочное, кг
# 1602  Мороженое сливочное, кг
#
# [48452 rows x 3 columns]

# %%
files_combined.to_csv('files_combined.csv',
                      index=False)
